# %% [markdown]
# <a href="https://colab.research.google.com/github/maha1606-gitoctocat/Main-Project---Electric-Vehicle-Population-Analysis-using-Python/blob/main/Final_Project_FORMAT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Project Title

# %% [markdown]
# #Objective

# %% [markdown]
# Maintain all sales information (customers, products, orders, revenue, regions, salespersons) in one structured location.
#
# Monitor total sales, revenue, profit, and quantity sold over time.
#
# Evaluate performance by product, region, salesperson, and channel.

# %% [markdown]
# #Dataset information
#
# Source : UCI Machine Learning Repository /
# Government Portals / Company Internal Dataset / Open Data Portals
#
# Location : specific geographic region (e.g., Portugal, USA, India) or organization (e.g., XYZ Company, ABC University).
#
# Year/Timeline : Data collected during the period YYYY to YYYY
#
# Domain: Healthcare, Education, Finance, Banking, Retail / E-commerce

# %% [markdown]
# #**Stage 1**
# **NOTE : THINGS TO BE COMPLETED**
#
# * Choose dataset and Define the business problem and expected outcome
#
# * Explain its source, size, and features
#
# * Import libraries, load dataset
#
# * Dataset description (rows, columns, features)
#
# * Initial EDA (head, info, describe, shape, null checks, duplicate check)

# %%
#Import Libraries

# %%
#Load the Data Set from git hub

# %%
#Initial EDA

# %% [markdown]
# # **Stage 2**
#
# **Data Cleaning,Data Transformation  and Feature Engineering**
#
# Handle duplicates
#
# Handle missing values (impute or drop)
#
# column name rename or dropping unwanted columns
#
# Treat outliers if required(optional)
#
# Convert data types if needed
#
# Data Transformation or Data Wrangling
#
# Final EDA

# %%
#Check the Duplicates

# %%
#Drop the Duplicates

# %%
#find the missing value

# %%
#Handle the missing value ( dont drop )

# %%
#Recheck the missing value

# %%
#Data Transformation or Data Wrangling

# %% [markdown]
# # **Stage 3**
#
#
# # **Statistical analysis & Visualizations**

# %%
# MEASURE OF CENTRAL TENDENCY + Chart

# %% [markdown]
# Interpretation of your above chart

# %%
# Variance and Standard Deviation

# %% [markdown]
# Interpretation of your above chart

# %%
# Skewness and Kurtosis , box plot outlier detection  and removal (optional)

# %% [markdown]
# Interpretation of your above chart

# %% [markdown]
# **Visualizations**

# %% [markdown]
# Univariate Analysis → distribution of single variables (countplot, histogram, boxplot)
#
# Bivariate Analysis → relation between two variables (scatterplot, barplot, correlation heatmap)
#
# Multivariate Analysis → relation among 3+ variables (pairplot, grouped analysis, pivot tables, advanced plots)
#
# Interpretation MUST with every visualization
#
# Focus on business story not just charts
#
# Each chart must be in seperate cells.

# %% [markdown]
# #1. Univariate Analysis (3–5 Visuals)

# %%
#1.

# %% [markdown]
# **Interpretation of your above chart**
# Explain the Chart.
#
# What is it saying?
#
# What features/columns you used?
#
# From this what you are showing us?

# %%
#2.

# %% [markdown]
# Interpretation

# %%
#3.

# %% [markdown]
# Interpretation

# %% [markdown]
# #2. Bivariate Analysis (3- 4 Visuals)

# %%
#1 .

# %% [markdown]
# Interpretation

# %%
#2 .

# %% [markdown]
# Interpretation

# %% [markdown]
# #3. Multivariate Analysis (2-3 Visuals)

# %%
#1 .

# %% [markdown]
# Interpretation

# %%
#1 .

# %% [markdown]
# Interpretation

# %% [markdown]
# # **Stage 4**
#
#
# # **Documentation, Insights & Presentation**

# %% [markdown]
# Summary of Findings (Plain English)
# Key Insights (3–5)
#
#
# **Types of Analysis**
#
# Descriptive Analysis
#
# Diagnostic Analysis
#
# Predictive Analysis
#
# Prescriptive Analysis
#
# **Recommendations / Decision Support**

# %% [markdown]
# # **Future Enhancement**

# %% [markdown]
# Use a larger or more recent dataset for deeper insights
#
# Automate parts of the analysis with scripts or dashboards
#
# Extend the analysis to predictive modeling for forecasting if needed
